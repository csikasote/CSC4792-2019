# %%
# Import common python libraries
import numpy as np
import pandas as pd
import os

# Matplotlib for plotting figures
import matplotlib as mpl
import matplotlib.pyplot as plt

# Where to save the figures
EXERCISE_ROOT_DIR = "."
IMAGES_PATH = os.path.join(EXERCISE_ROOT_DIR, "images")

# %%
# The function allows images to be saved
def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
# load the preprocessed iris dataset
dataset = pd.read_csv('datasets/iris_process.data',
                      delimiter=',',
                      header=None, 
                      names=['sepal length', 'sepal width', 'petal length', 'petal width','class'])

print('\nNumber of records:',len(dataset))
print('\nclass domain:', dataset['class'].unique())
print('\n\n',dataset.head())
# Out:
# Number of records: 150
#
# class domain: [0 1]
#
#
#     sepal length  sepal width  petal length  petal width  class
# 0           5.1          3.5           1.4          0.2      0
# 1           4.9          3.0           1.4          0.2      0
# 2           4.7          3.2           1.3          0.2      0
# 3           4.6          3.1           1.5          0.2      0
# 4           5.0          3.6           1.4          0.2      0

# %%
X = pd.DataFrame(dataset,columns=['sepal length','sepal width']).values
y = dataset['class'].values

# %%
def plot_dataset(X,y):
    plt.scatter(X[y == 0, 0],X[y == 0, 1],
                s=50, c='lightgreen',
                marker='o', edgecolor='black',label='class 1')
    plt.scatter(X[y == 1, 0],X[y == 1, 1],
                s=50, c='orange',
                marker='v', edgecolor='black',
                label='class 2')
    plt.legend(scatterpoints=1)
    plt.tight_layout()
    plt.xlabel("sepal length", fontsize=14)
    plt.ylabel("sepal width", fontsize=14)
    plt.axis([4.0,8.5,2.0,4.5])

# %%
plt.figure(1)
plt.title('figure 1. Iris data: sepal length vs. sepal width')
plot_dataset(X,y)
plt.grid(True)
save_fig("TR_DATASET")
plt.show()
# Out:
# Saving figure TR_DATASET

# %%
def fullBayes(X, y):
    parameters = []
    # Calculate the mean and variance of each feature for each class
    for c in np.unique(y):
        X_c = X[np.where(y == c)]
        mu = np.mean(X_c, axis= 0)
        prior = np.mean(y==c)
        z = X_c - mu.T
        sigma = (1/len(X_c)) * np.dot(z.T,z)
        params = {"mean": mu, "sigma": sigma, "prior": prior}
        parameters.append(params)
    return parameters

# %%
parameters = fullBayes(X, y)
print('\nclass 1 parameters:',parameters[0])
print('class 2 parameters:',parameters[1])
# Out:
# class 1 parameters: {'mean': array([5.006, 3.418]), 'sigma': array([[0.121764, 0.098292],
#        [0.098292, 0.142276]]), 'prior': 0.3333333333333333}
# class 2 parameters: {'mean': array([6.262, 2.872]), 'sigma': array([[0.434956, 0.120936],
#        [0.120936, 0.109616]]), 'prior': 0.6666666666666666}

# %%
def likelihood(X, mu, sigma):
    sigma_sqrd_det = np.linalg.det(sigma)  
    sigma_sqrd_inv = np.linalg.pinv(sigma)  
    X_diff = X - mu
    eqn_part1 = 1/((2*np.pi)**(len(mu)/2.0) * sigma_sqrd_det**(0.5))
    eqn_part2 = np.exp(-0.5 * (X_diff.dot(sigma_sqrd_inv) * X_diff).sum(axis=1))
    return eqn_part1 * eqn_part2

# %%
test = [[6.75, 4.25]]
likelihood1 = likelihood(test, parameters[0]["mean"], parameters[0]["sigma"])
print('\nLikelihood for class 1:',likelihood1[0])
likelihood2 = likelihood(test, parameters[1]["mean"], parameters[1]["sigma"])
print('Likelihood for class 2:',likelihood2[0])
# Out:
# Likelihood for class 1: 4.914117468104987e-07
# Likelihood for class 2: 2.5890082873828884e-05

# %%
def density(parameters, n_classes):
    density_contour_params = []
    for i in n_classes:
        linespace = np.arange(0, 10, 0.1)
        xx, yy = np.meshgrid(linespace, linespace)
        Z = likelihood(np.c_[xx.ravel(), yy.ravel()],
                       parameters[i]['mean'],
                       parameters[i]['sigma']);
        Z = Z.reshape(xx.shape)
        dimension = {'x':xx, 'y':yy, 'z':Z}
        density_contour_params.append(dimension)
    return density_contour_params

# %%
density_contour_params = density(parameters, np.unique(y))

x1 = density_contour_params[0]['x']
y1 = density_contour_params[0]['y']
z1 = density_contour_params[0]['z']

x2 = density_contour_params[1]['x']
y2 = density_contour_params[1]['y']
z2 = density_contour_params[1]['z']

plt.figure(2)
plt.title('figure 2: full bayes classifier class density contours')
plt.contour(x1,y1,z1)
plt.contour(x2,y2,z2)
plot_dataset(X,y)
plt.plot(6.75,4.25,'s', color='blue', markersize=10)
plt.plot(5.006, 3.418,'o', color='black', markersize=10)
plt.plot(6.262, 2.872,'v', color='black', markersize=10)
plt.axis([4,8.5, 2.0, 4.5])
plt.annotate("X=(6.75, 4.25)",
             xy=(6.78, 4.25),
             xytext=(6.8, 4.4),
             ha="center",
             fontsize=8,
            )
plt.grid(False)
save_fig("FB_DENSITY_CONTOURS")
plt.show()
# Out:
# Saving figure FB_DENSITY_CONTOURS

# %%
def posterior(sample,parameters,n_classes):
    posteriors = []
    for i in n_classes:
        likelihood_prob = likelihood(sample, parameters[i]["mean"], parameters[i]["sigma"])
        posterior =  parameters[i]['prior'] * likelihood_prob
        posteriors.append(posterior)
    return posteriors

# %%
posteriors = posterior(test, parameters,np.unique(y))
print('\nThe posterior probability for class 1:',posteriors[0][0])
print('The posterior probability for class 2:',posteriors[1][0])
# Out:
# The posterior probability for class 1: 1.6380391560349958e-07
# The posterior probability for class 2: 1.7260055249219256e-05

# %%
def classify(n_classes,posteriors):
    y_hat = n_classes[np.argmax(posteriors)]
    if y_hat == 0:
        print('class 1.')
    elif y_hat == 1:
        print('class 2.')

# %%
classify(np.unique(y),posteriors)
# Out:
# class 2.

# %% [markdown]
# ### Reference book###
#     1. Mohammed, J & Wagner(2014), M, Data mining and Analysis: Fundamental Concepts and Algorithms, p469
